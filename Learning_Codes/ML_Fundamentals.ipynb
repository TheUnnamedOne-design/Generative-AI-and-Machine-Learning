# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("credit_data.csv")



print(df.shape)
print(df.isnull().sum())
print(df.describe())
# Out:
# (300, 18)
# id                   0
# customer_id          0
# name                 0
# age                  0
# income              15
# debt                 9
# credit_score         0
# num_accounts         0
# employment_type      0
# risk_grade           0
# region               0
# credit_limit         0
# used_credit          0
# revenue              0
# profit               0
# ebitda               0
# interest_expense     0
# default              0
# dtype: int64
#                id         age         income          debt  credit_score  ...        revenue        profit        ebitda  interest_expense     default
# count  300.000000  300.000000     285.000000    291.000000    300.000000  ...     300.000000    300.000000    300.000000        300.000000  300.000000
# mean   148.873333   44.163333   54906.764912  17582.206186    680.313333  ...   72850.530000  14230.933333  23647.270000       2082.200000    0.243333
# std     85.865906   12.749581   17719.744926  11252.656350     77.729540  ...   30076.572028   9020.472150  15325.382011       1578.922729    0.429812
# min      1.000000   21.000000   12000.000000    500.000000    388.000000  ...   16085.000000   1709.000000   3108.000000        100.000000    0.000000
# 25%     74.750000   34.000000   42473.000000   8586.000000    635.000000  ...   51409.000000   7243.500000  12141.500000        950.250000    0.000000
# 50%    148.500000   44.000000   55590.000000  16967.000000    683.000000  ...   67140.000000  12625.000000  19855.500000       1902.500000    0.000000
# 75%    223.250000   55.000000   65488.000000  25001.000000    729.000000  ...   91750.250000  19305.750000  31728.750000       2854.500000    0.000000
# max    297.000000   67.000000  107291.000000  49172.000000    850.000000  ...  172290.000000  57716.000000  85700.000000       8097.000000    1.000000
#
# [8 rows x 13 columns]
