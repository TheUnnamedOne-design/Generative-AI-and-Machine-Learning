# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report

data=pd.read_csv("credit_data.csv")
df=pd.DataFrame(data)

print(df.shape)
#print(df.isnull().sum())


df["income"]=df["income"].fillna(df["income"].median())
df["debt"]=df["debt"].fillna(df["debt"].median())
#print(df.isnull().sum())


df=df.drop(columns={"customer_id","name","employment_type","risk_grade","region"})

X=df.drop(columns=["default"])
Y=df["default"]


X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.7,
    stratify=Y,
    random_state=42
)
# Out:
# (300, 18)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(X_train,Y_train)

Y_pred = model . predict ( X_test)

print(accuracy_score(Y_test,Y_pred))
print(classification_report(Y_test,Y_pred))
# Out:
# 0.7333333333333333
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       159
#            1       0.35      0.12      0.18        51
#
#     accuracy                           0.73       210
#    macro avg       0.56      0.52      0.51       210
# weighted avg       0.67      0.73      0.68       210

# %%
# Implementing Three way split for ML Fundamentals

# %%
X_temp, X_test, Y_temp, Y_test=train_test_split(
    X,Y,
    test_size=0.2,
    random_state=42
)

X_train,X_validate,Y_train,Y_validate=train_test_split(
    X_temp,Y_temp,
    test_size=0.2,
    random_state=42
)

print ( X_train .shape , X_validate .shape , X_test . shape )
# Out:
# (192, 12) (48, 12) (60, 12)

# %%
from sklearn.impute import SimpleImputer

imputer=SimpleImputer(strategy="median")
imputer.fit(X_train)

X_train_imp=imputer.transform(X_train)
X_test_imp=imputer.transform(X_test)

X_train_imp
# Out:
# array([[2.2000e+02, 6.3000e+01, 4.1615e+04, ..., 5.5860e+03, 1.1817e+04,
#         2.1230e+03],
#        [5.6000e+01, 2.3000e+01, 5.6631e+04, ..., 1.1879e+04, 2.1266e+04,
#         1.0000e+02],
#        [8.9000e+01, 5.7000e+01, 4.3225e+04, ..., 2.1807e+04, 3.3704e+04,
#         1.0000e+03],
#        ...,
#        [2.2400e+02, 3.0000e+01, 5.5206e+04, ..., 2.0574e+04, 4.2512e+04,
#         2.0490e+03],
#        [2.2800e+02, 4.8000e+01, 6.4974e+04, ..., 1.2171e+04, 2.2945e+04,
#         2.2400e+03],
#        [1.3000e+01, 5.5000e+01, 3.3671e+04, ..., 6.2930e+03, 1.3760e+04,
#         2.7560e+03]], shape=(192, 12))

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler


scaler=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder


encoder=OneHotEncoder(
    handle_unknown="ignore",
    sparse_output=False
)

df.info()
#print(X_train[""])

#encoder.fit(X_train[[]])
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                300 non-null    int64
#  1   age               300 non-null    int64
#  2   income            300 non-null    float64
#  3   debt              300 non-null    float64
#  4   credit_score      300 non-null    int64
#  5   num_accounts      300 non-null    int64
#  6   credit_limit      300 non-null    float64
#  7   used_credit       300 non-null    float64
#  8   revenue           300 non-null    float64
#  9   profit            300 non-null    float64
#  10  ebitda            300 non-null    float64
#  11  interest_expense  300 non-null    float64
#  12  default           300 non-null    int64
# dtypes: float64(8), int64(5)
# memory usage: 30.6 KB
