# %%
import pandas as pd

# %%
data=pd.read_csv("credit_data.csv")
data
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
# 297   38    CUST0038  Customer_038   59  62718.0  35199.0           685
# 298  129    CUST0129  Customer_129   48  61945.0  21144.0           676
# 299  242    CUST0242  Customer_242   48  59973.0  12251.0           698
#
#      num_accounts employment_type risk_grade region  credit_limit  \
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
# 297   38    CUST0038  Customer_038   59  62718.0  35199.0           685
# 298  129    CUST0129  Customer_129   48  61945.0  21144.0           676
# 299  242    CUST0242  Customer_242   48  59973.0  12251.0           698
#
#      num_accounts employment_type risk_grade region  credit_limit  \
# ...

# %%
df.head()
df.tail(105)
print(df.shape)
print(df.columns.tolist())
# Out:
# (300, 18)
# ['id', 'customer_id', 'name', 'age', 'income', 'debt', 'credit_score', 'num_accounts', 'employment_type', 'risk_grade', 'region', 'credit_limit', 'used_credit', 'revenue', 'profit', 'ebitda', 'interest_expense', 'default']

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                300 non-null    int64
#  1   customer_id       300 non-null    str
#  2   name              300 non-null    str
#  3   age               300 non-null    int64
#  4   income            285 non-null    float64
#  5   debt              291 non-null    float64
#  6   credit_score      300 non-null    int64
#  7   num_accounts      300 non-null    int64
#  8   employment_type   300 non-null    str
#  9   risk_grade        300 non-null    str
#  10  region            300 non-null    str
#  11  credit_limit      300 non-null    float64
#  12  used_credit       300 non-null    float64
#  13  revenue           300 non-null    float64
#  14  profit            300 non-null    float64
#  15  ebitda            300 non-null    float64
#  16  interest_expense  300 non-null    float64
# ...

# %%
df[df["age"]>44]
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 5      6    CUST0006  Customer_006   61  24856.0  22601.0           824
# 7      8    CUST0008  Customer_008   53  54032.0  22185.0           650
# 10    11    CUST0011  Customer_011   45  72689.0  18833.0           656
# ..   ...         ...           ...  ...      ...      ...           ...
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
# 297   38    CUST0038  Customer_038   59  62718.0  35199.0           685
# 298  129    CUST0129  Customer_129   48  61945.0  21144.0           676
# 299  242    CUST0242  Customer_242   48  59973.0  12251.0           698
#
#      num_accounts employment_type risk_grade region  credit_limit  \
# ...

# %%
df[["id","num_accounts","default"]]
# Out:
#       id  num_accounts  default
# 0      1             5        0
# 1      2             2        0
# 2      3            10        0
# 3      4             9        0
# 4      5             9        1
# ..   ...           ...      ...
# 295  296             4        0
# 296  297             1        1
# 297   38             7        1
# 298  129             5        0
# 299  242            10        1
#
# [300 rows x 3 columns]

# %%
df.loc[100:156]
# Out:
#       id customer_id          name  age    income     debt  credit_score  \
# 100  101    CUST0101  Customer_101   60   88064.0  14959.0           683
# 101  102    CUST0102  Customer_102   30  107291.0  16090.0           820
# 102  103    CUST0103  Customer_103   58   33912.0  20441.0           673
# 103  104    CUST0104  Customer_104   21   48372.0   5898.0           690
# 104  105    CUST0105  Customer_105   58   61148.0  26482.0           709
# 105  106    CUST0106  Customer_106   57   86117.0  25952.0           850
# 106  107    CUST0107  Customer_107   57   37237.0  22620.0           748
# 107  108    CUST0108  Customer_108   52   50585.0  24678.0           623
# 108  109    CUST0109  Customer_109   43   68992.0  21557.0           758
# 109  110    CUST0110  Customer_110   54   62826.0  42421.0           651
# 110  111    CUST0111  Customer_111   34   48229.0  16955.0           641
# 111  112    CUST0112  Customer_112   57   52591.0  14315.0           753
# ...

# %%
df. iloc [0:5 , 2]
# Out:
# 0    Customer_001
# 1    Customer_002
# 2    Customer_003
# 3    Customer_004
# 4    Customer_005
# Name: name, dtype: str

# %%
df.isnull().sum()
# Out:
# id                   0
# customer_id          0
# name                 0
# age                  0
# income              15
# debt                 9
# credit_score         0
# num_accounts         0
# employment_type      0
# risk_grade           0
# region               0
# credit_limit         0
# used_credit          0
# revenue              0
# profit               0
# ebitda               0
# interest_expense     0
# default              0
# dtype: int64

# %%
df.fillna(0,inplace=True)
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
# 297   38    CUST0038  Customer_038   59  62718.0  35199.0           685
# 298  129    CUST0129  Customer_129   48  61945.0  21144.0           676
# 299  242    CUST0242  Customer_242   48  59973.0  12251.0           698
#
#      num_accounts employment_type risk_grade region  credit_limit  \
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# customer_id         0
# name                0
# age                 0
# income              0
# debt                0
# credit_score        0
# num_accounts        0
# employment_type     0
# risk_grade          0
# region              0
# credit_limit        0
# used_credit         0
# revenue             0
# profit              0
# ebitda              0
# interest_expense    0
# default             0
# dtype: int64

# %%
df.rename(columns={"num_accounts":"account_count"},inplace=True)

# %%
df
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
# 297   38    CUST0038  Customer_038   59  62718.0  35199.0           685
# 298  129    CUST0129  Customer_129   48  61945.0  21144.0           676
# 299  242    CUST0242  Customer_242   48  59973.0  12251.0           698
#
#      account_count employment_type risk_grade region  credit_limit  \
# ...

# %%
df["employment_type"].value_counts()
# Out:
# employment_type
# Salaried         193
# Self-Employed     69
# Unemployed        38
# Name: count, dtype: int64

# %%
df.groupby("employment_type")["credit_score"].mean()
# Out:
# employment_type
# Salaried         681.367876
# Self-Employed    672.710145
# Unemployed       688.763158
# Name: credit_score, dtype: float64

# %%
df.sort_values("income",ascending=False)
# Out:
#       id customer_id          name  age    income     debt  credit_score  \
# 101  102    CUST0102  Customer_102   30  107291.0  16090.0           820
# 79    80    CUST0080  Customer_080   52  100315.0  15704.0           642
# 228  229    CUST0229  Customer_229   46   96898.0   9434.0           683
# 97    98    CUST0098  Customer_098   53   93326.0   8085.0           827
# 15    16    CUST0016  Customer_016   57   93312.0  17690.0           606
# ..   ...         ...           ...  ...       ...      ...           ...
# 52    53    CUST0053  Customer_053   38       0.0    500.0           711
# 23    24    CUST0024  Customer_024   64       0.0  41247.0           707
# 252  253    CUST0253  Customer_253   29       0.0    500.0           785
# 51    52    CUST0052  Customer_052   30       0.0  29227.0           721
# 272  273    CUST0273  Customer_273   28       0.0    500.0           548
#
#      account_count employment_type risk_grade region  credit_limit  \
# ...

# %%
data2=pd.read_csv("customer_additional_data.csv")
df2=pd.DataFrame(data2)
df2

df
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
# 297   38    CUST0038  Customer_038   59  62718.0  35199.0           685
# 298  129    CUST0129  Customer_129   48  61945.0  21144.0           676
# 299  242    CUST0242  Customer_242   48  59973.0  12251.0           698
#
#      account_count employment_type risk_grade region  credit_limit  \
# ...

# %%
merged=df.merge(df2,on="customer_id",how="left")
merged
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
# 297   38    CUST0038  Customer_038   59  62718.0  35199.0           685
# 298  129    CUST0129  Customer_129   48  61945.0  21144.0           676
# 299  242    CUST0242  Customer_242   48  59973.0  12251.0           698
#
#      account_count employment_type risk_grade  ... credit_limit  used_credit  \
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                         id       age    income      debt  credit_score  \
# id                1.000000 -0.070946 -0.013412 -0.079465     -0.034641
# age              -0.070946  1.000000  0.076608  0.147815     -0.055415
# income           -0.013412  0.076608  1.000000  0.067482      0.029927
# debt             -0.079465  0.147815  0.067482  1.000000     -0.095300
# credit_score     -0.034641 -0.055415  0.029927 -0.095300      1.000000
# account_count    -0.081002  0.051852 -0.120147  0.144114      0.005784
# credit_limit      0.002083  0.023427  0.621185  0.064824      0.069736
# used_credit      -0.065171  0.079528  0.098064  0.790950     -0.110543
# revenue          -0.039022  0.014004  0.660076  0.038728      0.016857
# profit           -0.000717  0.036605  0.414471  0.029722      0.029687
# ebitda            0.005017  0.024303  0.409662  0.035027     -0.001881
# interest_expense -0.093920  0.140622  0.091138  0.808303     -0.102813
# ...

# %%
high_risk=df[df["credit_score"]<600]
high_risk
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 11    12    CUST0012  Customer_012   66  46013.0  19922.0           599
# 24    25    CUST0025  Customer_025   57  63029.0  31272.0           537
# 27    28    CUST0028  Customer_028   59  31997.0  13115.0           578
# 35    36    CUST0036  Customer_036   23  47603.0  49172.0           593
# 38    39    CUST0039  Customer_039   34  82644.0  19098.0           576
# 47    48    CUST0048  Customer_048   62  35073.0  22398.0           593
# 50    51    CUST0051  Customer_051   56  47897.0  14296.0           580
# 53    54    CUST0054  Customer_054   42  61076.0  13973.0           537
# 60    61    CUST0061  Customer_061   64  33061.0      0.0           593
# 66    67    CUST0067  Customer_067   63  46285.0    500.0           580
# ...

# %%
df.duplicated().sum()
df.drop_duplicates( inplace = True )

df
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 292  293    CUST0293  Customer_293   65  62702.0  27333.0           719
# 293  294    CUST0294  Customer_294   36  51594.0  27684.0           638
# 294  295    CUST0295  Customer_295   46  60916.0    500.0           680
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
#
#      account_count employment_type risk_grade region  credit_limit  \
# ...

# %%
df["debt_ratio"]=df["debt"]/df["income"]
df["utilization"]=df["used_credit"]/df["credit_limit"]
df["profit_margin"]=df["profit"]/df["revenue"]
df
# Out:
#       id customer_id          name  age   income     debt  credit_score  \
# 0      1    CUST0001  Customer_001   25  52466.0  13887.0           775
# 1      2    CUST0002  Customer_002   57  74188.0    500.0           598
# 2      3    CUST0003  Customer_003   51  57827.0  30807.0           531
# 3      4    CUST0004  Customer_004   41  52145.0  14022.0           688
# 4      5    CUST0005  Customer_005   41  36358.0  31375.0           754
# ..   ...         ...           ...  ...      ...      ...           ...
# 292  293    CUST0293  Customer_293   65  62702.0  27333.0           719
# 293  294    CUST0294  Customer_294   36  51594.0  27684.0           638
# 294  295    CUST0295  Customer_295   46  60916.0    500.0           680
# 295  296    CUST0296  Customer_296   45  61515.0    500.0           759
# 296  297    CUST0297  Customer_297   60  78772.0  30021.0           635
#
#      account_count employment_type risk_grade  ... credit_limit  used_credit  \
# ...

# %%
df["risk_grade"].unique()
df["risk_grade"].value_counts()
# Out:
# risk_grade
# A    93
# B    93
# C    73
# D    38
# Name: count, dtype: int64

# %%
# Now this is a pipeline for data preparation

# %%
import pandas as pd

data=pd.read_csv("credit_data.csv")
df=pd.DataFrame(data)

df.drop(columns={"customer_id","name"},inplace=True)
df
# Out:
#       id  age   income     debt  credit_score  num_accounts employment_type  \
# 0      1   25  52466.0  13887.0           775             5        Salaried
# 1      2   57  74188.0    500.0           598             2   Self-Employed
# 2      3   51  57827.0  30807.0           531            10   Self-Employed
# 3      4   41  52145.0  14022.0           688             9        Salaried
# 4      5   41  36358.0  31375.0           754             9   Self-Employed
# ..   ...  ...      ...      ...           ...           ...             ...
# 295  296   45  61515.0    500.0           759             4        Salaried
# 296  297   60  78772.0  30021.0           635             1      Unemployed
# 297   38   59  62718.0  35199.0           685             7        Salaried
# 298  129   48  61945.0  21144.0           676             5        Salaried
# 299  242   48  59973.0  12251.0           698            10        Salaried
#
# ...

# %%
df["income"]=df["income"].fillna(df["income"].median())
df.isnull().sum()

df["employment_type"]=df["employment_type"].fillna("Unknown")
df.drop_duplicates(inplace=True)

df
# Out:
#       id  age   income     debt  credit_score  num_accounts employment_type  \
# 0      1   25  52466.0  13887.0           775             5        Salaried
# 1      2   57  74188.0    500.0           598             2   Self-Employed
# 2      3   51  57827.0  30807.0           531            10   Self-Employed
# 3      4   41  52145.0  14022.0           688             9        Salaried
# 4      5   41  36358.0  31375.0           754             9   Self-Employed
# ..   ...  ...      ...      ...           ...           ...             ...
# 292  293   65  62702.0  27333.0           719             7   Self-Employed
# 293  294   36  51594.0  27684.0           638             9   Self-Employed
# 294  295   46  60916.0    500.0           680             1        Salaried
# 295  296   45  61515.0    500.0           759             4        Salaried
# 296  297   60  78772.0  30021.0           635             1      Unemployed
#
# ...

# %%
df["debt_ratio"]=df["debt"]/df["income"]
print(df.describe())
print(df["default"].value_counts())
# Out:
#                id         age         income          debt  credit_score  \
# count  297.000000  297.000000     297.000000    288.000000    297.000000
# mean   149.000000   44.087542   54874.215488  17527.180556    680.252525
# std     85.880731   12.780861   17344.234079  11256.918609     78.114782
# min      1.000000   21.000000   12000.000000    500.000000    388.000000
# 25%     75.000000   34.000000   43223.000000   8501.000000    635.000000
# 50%    149.000000   44.000000   55590.000000  16961.000000    683.000000
# 75%    223.000000   55.000000   64541.000000  24978.000000    729.000000
# max    297.000000   67.000000  107291.000000  49172.000000    850.000000
#
#        num_accounts  credit_limit   used_credit        revenue        profit  \
# count    297.000000     297.00000    297.000000     297.000000    297.000000
# mean       5.313131  176135.86532  27605.875421   72716.043771  14148.518519
# std        2.861604   84799.26468  13659.899641   30148.290583   9027.448090
# ...

# %%
X=df.drop(columns={"default"})
Y=df["default"]

X,Y
# Out:
# (      id  age   income     debt  credit_score  num_accounts employment_type  \
#  0      1   25  52466.0  13887.0           775             5        Salaried
#  1      2   57  74188.0    500.0           598             2   Self-Employed
#  2      3   51  57827.0  30807.0           531            10   Self-Employed
#  3      4   41  52145.0  14022.0           688             9        Salaried
#  4      5   41  36358.0  31375.0           754             9   Self-Employed
#  ..   ...  ...      ...      ...           ...           ...             ...
#  292  293   65  62702.0  27333.0           719             7   Self-Employed
#  293  294   36  51594.0  27684.0           638             9   Self-Employed
#  294  295   46  60916.0    500.0           680             1        Salaried
#  295  296   45  61515.0    500.0           759             4        Salaried
#  296  297   60  78772.0  30021.0           635             1      Unemployed
#
# ...
